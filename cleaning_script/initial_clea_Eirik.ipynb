# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", 80)
pd.set_option("display.precision", 2)

dropped_columns = []

# %%
# Read in the data
df = pd.read_csv('../original_do_not_change.csv')
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0    6983    https://www.airbnb.com/rooms/6983  20220624204326   2022-06-25
# 1   26057   https://www.airbnb.com/rooms/26057  20220624204326   2022-06-25
# 2   26473   https://www.airbnb.com/rooms/26473  20220624204326   2022-06-25
# 3   29118   https://www.airbnb.com/rooms/29118  20220624204326   2022-06-25
# 4  670820  https://www.airbnb.com/rooms/670820  20220624204326   2022-06-25
#
#                                         name  \
# 0                       Copenhagen 'N Livin'
# 1        Lovely house - most attractive area
# 2  City Centre Townhouse Sleeps 1-10 persons
# 3            Best Location in Cool Istedgade
# 4        1 Bedroom Apartment 5 min to Centre
#
#                                          description  \
# 0  Lovely apartment located in the hip Nørrebro a...
# 1  Our lovely house in the center of the city is ...
# 2  GUESTHOUSE ON KNABROSTRÆDE - located in the ab...
# 3  <b>The space</b><br />The apartment is situate...
# 4  The flat is located close to the city center -...
#
#                                neighborhood_overview  \
# 0  Nice bars and cozy cafes just minutes away, ye...
# 1  The neighborhood is the most famous one and th...
# 2                                                NaN
# 3                                                NaN
# 4  The flat is surrounded by parks and streets th...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/42044170/f63c...    16774
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   109777
# 2  https://a0.muscache.com/pictures/8e132ba0-b68c...   112210
# 3  https://a0.muscache.com/pictures/b83c7003-367a...   125230
# 4  https://a0.muscache.com/pictures/91442571/8563...  1566921
#
#                                     host_url host_name  host_since  \
# 0    https://www.airbnb.com/users/show/16774     Simon  2009-05-12
# 1   https://www.airbnb.com/users/show/109777      Kari  2010-04-17
# 2   https://www.airbnb.com/users/show/112210     Julia  2010-04-22
# 3   https://www.airbnb.com/users/show/125230      Nana  2010-05-15
# 4  https://www.airbnb.com/users/show/1566921   Mihaela  2012-01-04
#
#                                     host_location  \
# 0                              København, Denmark
# 1                              København, Denmark
# 2                             Copenhagen, Denmark
# 3                             Copenhagen, Denmark
# 4  Copenhagen, Capital Region of Denmark, Denmark
#
#                                           host_about host_response_time  \
# 0  I'm currently working as an environmental cons...       within a day
# 1  We are a family with 2 children, and living in...     within an hour
# 2  Active young woman, started as an expat in Cop...     within an hour
# 3  I have a Master of Arts in Musicology and I wo...       within a day
# 4  I truly enjoy interacting with people from dif...                NaN
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                90%                  55%                 f
# 1               100%                  38%                 f
# 2               100%                  94%                 f
# 3               100%                  14%                 f
# 4                NaN                  NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/16774/profile...
# 1  https://a0.muscache.com/im/users/109777/profil...
# 2  https://a0.muscache.com/im/pictures/user/8a185...
# 3  https://a0.muscache.com/im/users/125230/profil...
# 4  https://a0.muscache.com/im/users/1566921/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/16774/profile...           Nørrebro
# 1  https://a0.muscache.com/im/users/109777/profil...           Indre By
# 2  https://a0.muscache.com/im/pictures/user/8a185...           Indre By
# 3  https://a0.muscache.com/im/users/125230/profil...          Vesterbro
# 4  https://a0.muscache.com/im/users/1566921/profi...           Indre By
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  1.0                        1.0
# 2                 11.0                       11.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2  ['email', 'phone', 'work_email']                    t
# 3                ['email', 'phone']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified                     neighbourhood  \
# 0                      f  Copenhagen, Hovedstaden, Denmark
# 1                      t  Copenhagen, Hovedstaden, Denmark
# 2                      t                               NaN
# 3                      t                               NaN
# 4                      f               Copenhagen, Denmark
#
#       neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# 0                    Nrrebro                           NaN     55.69
# 1                   Indre By                           NaN     55.69
# 2                   Indre By                           NaN     55.68
# 3  Vesterbro-Kongens Enghave                           NaN     55.67
# 4                   Indre By                           NaN     55.69
#
#    longitude       property_type        room_type  accommodates  bathrooms  \
# 0      12.55  Entire rental unit  Entire home/apt             2        NaN
# 1      12.58         Entire home  Entire home/apt             6        NaN
# 2      12.58    Entire townhouse  Entire home/apt            11        NaN
# 3      12.56  Entire rental unit  Entire home/apt             2        NaN
# 4      12.57  Entire rental unit  Entire home/apt             4        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       1.0   1.0
# 1      1.5 baths       4.0   4.0
# 2        2 baths       5.0   5.0
# 3         1 bath       1.0   1.0
# 4         1 bath       1.0   2.0
#
#                                            amenities      price  \
# 0  ["Stove", "Free washer \u2013 In unit", "Coffe...    $877.00
# 1  ["Private fenced garden or backyard", "Stove",...  $2,400.00
# 2  ["Essentials", "Cooking basics", "TV", "Stove"...  $3,350.00
# 3  ["Stove", "Children\u2019s books and toys", "W...    $725.00
# 4  ["Essentials", "Cooking basics", "TV", "Hot wa...  $1,116.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3              15                     3.0
# 1               4            1125                     4.0
# 2               3              31                     3.0
# 3               7              14                     5.0
# 4               3              14                     3.0
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                     3.0                    15.0                    15.0
# 1                     4.0                  1125.0                  1125.0
# 2                     3.0                  1125.0                  1125.0
# 3                     5.0                    14.0                    14.0
# 4                     3.0                    14.0                    14.0
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.0                    15.0               NaN
# 1                     4.0                  1125.0               NaN
# 2                     3.0                  1125.0               NaN
# 3                     5.0                    14.0               NaN
# 4                     3.0                    14.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0               22
# 1                t                0                3                9
# 2                t                3                3                3
# 3                t                3                3                3
# 4                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                22            2022-06-25                171
# 1               224            2022-06-25                 58
# 2                 3            2022-06-25                293
# 3                12            2022-06-25                 22
# 4                 0            2022-06-25                  8
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      3                       3   2009-09-04  2022-06-16
# 1                      8                       0   2013-12-02  2022-05-15
# 2                      0                       0   2010-10-14  2020-03-02
# 3                      0                       0   2010-06-17  2019-08-02
# 4                      0                       0   2015-08-07  2018-09-18
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.78                    4.78                       4.79
# 1                  4.91                    4.93                       4.96
# 2                  4.53                    4.62                       4.44
# 3                  4.91                    4.85                       4.77
# 4                  4.63                    4.38                       4.50
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.86                         4.89                    4.72
# 1                   4.92                         4.85                    4.94
# 2                   4.77                         4.69                    4.88
# 3                   5.00                         5.00                    4.85
# 4                   4.75                         4.88                    4.88
#
#    review_scores_value  license instant_bookable  \
# 0                 4.70      NaN                f
# 1                 4.81      NaN                f
# 2                 4.60      NaN                f
# 3                 4.77      NaN                f
# 4                 4.25      NaN                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                              11
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            6
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             5
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.10
# 1                                            0               0.56
# 2                                            0               2.06
# 3                                            0               0.15
# 4                                            0               0.10

# %%
df.describe(include='all')
# Out:
#               id                        listing_url  scrape_id last_scraped  \
# count   1.25e+04                              12495   1.25e+04        12495
# unique       NaN                              12495        NaN            2
# top          NaN  https://www.airbnb.com/rooms/6983        NaN   2022-06-25
# freq         NaN                                  1        NaN         9403
# mean    1.18e+17                                NaN   2.02e+13          NaN
# std     2.42e+17                                NaN   0.00e+00          NaN
# min     6.98e+03                                NaN   2.02e+13          NaN
# 25%     1.72e+07                                NaN   2.02e+13          NaN
# 50%     3.61e+07                                NaN   2.02e+13          NaN
# 75%     5.21e+07                                NaN   2.02e+13          NaN
# max     6.56e+17                                NaN   2.02e+13          NaN
#
#                                              name  \
# count                                       12495
# unique                                      12002
# top     Cozy apartment in the heart of Copenhagen
# freq                                           18
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#                                               description  \
# count                                               12156
# unique                                              11944
# top     Nyd det simple liv i denne fredelige og centra...
# freq                                                   22
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                     neighborhood_overview  \
# count                                                6461
# unique                                               6231
# top     Distance to most popular attractions:<br /><br...
# freq                                                   19
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               picture_url   host_id  \
# count                                               12495  1.25e+04
# unique                                              12386       NaN
# top     https://a0.muscache.com/pictures/950aadd4-4c99...       NaN
# freq                                                   11       NaN
# mean                                                  NaN  1.00e+08
# std                                                   NaN  1.23e+08
# min                                                   NaN  1.17e+04
# 25%                                                   NaN  1.29e+07
# 50%                                                   NaN  4.32e+07
# 75%                                                   NaN  1.47e+08
# max                                                   NaN  4.66e+08
#
#                                            host_url              host_name  \
# count                                         12495                  12494
# unique                                        11157                   3454
# top     https://www.airbnb.com/users/show/187610263  ApartmentinCopenhagen
# freq                                            181                    181
# mean                                            NaN                    NaN
# std                                             NaN                    NaN
# min                                             NaN                    NaN
# 25%                                             NaN                    NaN
# 50%                                             NaN                    NaN
# 75%                                             NaN                    NaN
# max                                             NaN                    NaN
#
#         host_since        host_location  \
# count        12494                12472
# unique        3456                  513
# top     2018-05-03  Copenhagen, Denmark
# freq           182                 4251
# mean           NaN                  NaN
# std            NaN                  NaN
# min            NaN                  NaN
# 25%            NaN                  NaN
# 50%            NaN                  NaN
# 75%            NaN                  NaN
# max            NaN                  NaN
#
#                                                host_about host_response_time  \
# count                                                6400               9658
# unique                                               5427                  4
# top     Vi udlejer møblerede lejligheder og har mere e...     within an hour
# freq                                                  181               4425
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# count                9658                10958             12494
# unique                 68                   99                 2
# top                  100%                 100%                 f
# freq                 7005                 3618             11581
# mean                  NaN                  NaN               NaN
# std                   NaN                  NaN               NaN
# min                   NaN                  NaN               NaN
# 25%                   NaN                  NaN               NaN
# 50%                   NaN                  NaN               NaN
# 75%                   NaN                  NaN               NaN
# max                   NaN                  NaN               NaN
#
#                                        host_thumbnail_url  \
# count                                               12494
# unique                                              10973
# top     https://a0.muscache.com/defaults/user_pic-50x5...
# freq                                                  187
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          host_picture_url host_neighbourhood  \
# count                                               12494               5391
# unique                                              10973                 35
# top     https://a0.muscache.com/defaults/user_pic-225x...           Nørrebro
# freq                                                  187                905
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#         host_listings_count  host_total_listings_count  host_verifications  \
# count              12494.00                   12494.00               12494
# unique                  NaN                        NaN                   7
# top                     NaN                        NaN  ['email', 'phone']
# freq                    NaN                        NaN               10318
# mean                   7.99                       7.99                 NaN
# std                   44.17                      44.17                 NaN
# min                    0.00                       0.00                 NaN
# 25%                    0.00                       0.00                 NaN
# 50%                    1.00                       1.00                 NaN
# 75%                    1.00                       1.00                 NaN
# max                  346.00                     346.00                 NaN
#
#        host_has_profile_pic host_identity_verified        neighbourhood  \
# count                 12494                  12494                 6461
# unique                    2                      2                  203
# top                       t                      t  Copenhagen, Denmark
# freq                  12307                  10467                 4733
# mean                    NaN                    NaN                  NaN
# std                     NaN                    NaN                  NaN
# min                     NaN                    NaN                  NaN
# 25%                     NaN                    NaN                  NaN
# 50%                     NaN                    NaN                  NaN
# 75%                     NaN                    NaN                  NaN
# max                     NaN                    NaN                  NaN
#
#            neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  \
# count                       12495                           0.0  12495.00
# unique                         11                           NaN       NaN
# top     Vesterbro-Kongens Enghave                           NaN       NaN
# freq                         2044                           NaN       NaN
# mean                          NaN                           NaN     55.68
# std                           NaN                           NaN      0.02
# min                           NaN                           NaN     55.61
# 25%                           NaN                           NaN     55.67
# 50%                           NaN                           NaN     55.68
# 75%                           NaN                           NaN     55.70
# max                           NaN                           NaN     55.74
#
#         longitude       property_type        room_type  accommodates  \
# count    12495.00               12495            12495      12495.00
# unique        NaN                  52                4           NaN
# top           NaN  Entire rental unit  Entire home/apt           NaN
# freq          NaN                5931            10982           NaN
# mean        12.56                 NaN              NaN          3.44
# std          0.03                 NaN              NaN          1.76
# min         12.44                 NaN              NaN          0.00
# 25%         12.54                 NaN              NaN          2.00
# 50%         12.56                 NaN              NaN          3.00
# 75%         12.58                 NaN              NaN          4.00
# max         12.65                 NaN              NaN         16.00
#
#         bathrooms bathrooms_text  bedrooms      beds  \
# count         0.0          12483  12277.00  12330.00
# unique        NaN             20       NaN       NaN
# top           NaN         1 bath       NaN       NaN
# freq          NaN           9429       NaN       NaN
# mean          NaN            NaN      1.69      2.07
# std           NaN            NaN      1.31      1.43
# min           NaN            NaN      1.00      1.00
# 25%           NaN            NaN      1.00      1.00
# 50%           NaN            NaN      1.00      2.00
# 75%           NaN            NaN      2.00      3.00
# max           NaN            NaN    101.00     24.00
#
#                                                 amenities      price  \
# count                                               12495      12495
# unique                                              11914       1783
# top     ["TV", "Paid parking on premises", "Wifi", "Sm...  $1,000.00
# freq                                                   23        499
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#         minimum_nights  maximum_nights  minimum_minimum_nights  \
# count         12495.00        12495.00                12494.00
# unique             NaN             NaN                     NaN
# top                NaN             NaN                     NaN
# freq               NaN             NaN                     NaN
# mean              4.60          494.46                    4.47
# std              17.12          509.22                   17.03
# min               1.00            1.00                    1.00
# 25%               2.00           20.00                    2.00
# 50%               3.00          365.00                    3.00
# 75%               4.00         1125.00                    4.00
# max            1111.00         4000.00                 1111.00
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# count                 12494.00                12494.00
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                      5.20                  588.87
# std                      18.96                  522.12
# min                       1.00                    1.00
# 25%                       2.00                   21.00
# 50%                       3.00                  365.00
# 75%                       5.00                 1125.00
# max                    1111.00                 4000.00
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# count                 12494.00                12494.00
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                    630.29                    4.83
# std                     518.43                   18.52
# min                       1.00                    1.00
# 25%                      29.00                    2.00
# 50%                    1125.00                    3.00
# 75%                    1125.00                    4.00
# max                    4000.00                 1111.00
#
#         maximum_nights_avg_ntm  calendar_updated has_availability  \
# count                 12494.00               0.0            12495
# unique                     NaN               NaN                2
# top                        NaN               NaN                t
# freq                       NaN               NaN            12424
# mean                    615.28               NaN              NaN
# std                     513.74               NaN              NaN
# min                       1.00               NaN              NaN
# 25%                      29.00               NaN              NaN
# 50%                     550.90               NaN              NaN
# 75%                    1125.00               NaN              NaN
# max                    4000.00               NaN              NaN
#
#         availability_30  availability_60  availability_90  availability_365  \
# count          12495.00         12495.00         12495.00          12495.00
# unique              NaN              NaN              NaN               NaN
# top                 NaN              NaN              NaN               NaN
# freq                NaN              NaN              NaN               NaN
# mean               5.73            10.64            16.53             90.92
# std                8.16            15.49            24.00            115.60
# min                0.00             0.00             0.00              0.00
# 25%                0.00             0.00             0.00              0.00
# 50%                1.00             4.00             6.00             22.00
# 75%                9.00            15.00            22.00            175.00
# max               30.00            60.00            90.00            365.00
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# count                  12495           12495.00               12495.00
# unique                     2                NaN                    NaN
# top               2022-06-25                NaN                    NaN
# freq                    9403                NaN                    NaN
# mean                     NaN              18.07                   4.48
# std                      NaN              35.85                  10.63
# min                      NaN               0.00                   0.00
# 25%                      NaN               1.00                   0.00
# 50%                      NaN               6.00                   1.00
# 75%                      NaN              20.00                   5.00
# max                      NaN             690.00                 460.00
#
#         number_of_reviews_l30d first_review last_review  review_scores_rating  \
# count                 12495.00        10191       10191              10191.00
# unique                     NaN         2607        1284                   NaN
# top                        NaN   2022-05-29  2022-06-19                   NaN
# freq                       NaN           64         597                   NaN
# mean                      0.69          NaN         NaN                  4.78
# std                       1.40          NaN         NaN                  0.44
# min                       0.00          NaN         NaN                  0.00
# 25%                       0.00          NaN         NaN                  4.71
# 50%                       0.00          NaN         NaN                  4.88
# 75%                       1.00          NaN         NaN                  5.00
# max                      25.00          NaN         NaN                  5.00
#
#         review_scores_accuracy  review_scores_cleanliness  \
# count                 10141.00                   10141.00
# unique                     NaN                        NaN
# top                        NaN                        NaN
# freq                       NaN                        NaN
# mean                      4.85                       4.70
# std                       0.27                       0.39
# min                       1.00                       1.00
# 25%                       4.80                       4.57
# 50%                       4.93                       4.82
# 75%                       5.00                       5.00
# max                       5.00                       5.00
#
#         review_scores_checkin  review_scores_communication  \
# count                10141.00                     10141.00
# unique                    NaN                          NaN
# top                       NaN                          NaN
# freq                      NaN                          NaN
# mean                     4.89                         4.91
# std                      0.24                         0.23
# min                      1.00                         1.00
# 25%                      4.86                         4.90
# 50%                      4.98                         5.00
# 75%                      5.00                         5.00
# max                      5.00                         5.00
#
#         review_scores_location  review_scores_value  license instant_bookable  \
# count                 10140.00             10141.00      0.0            12495
# unique                     NaN                  NaN      NaN                2
# top                        NaN                  NaN      NaN                f
# freq                       NaN                  NaN      NaN             9738
# mean                      4.83                 4.72      NaN              NaN
# std                       0.25                 0.32      NaN              NaN
# min                       1.00                 1.00      NaN              NaN
# 25%                       4.75                 4.62      NaN              NaN
# 50%                       4.90                 4.78      NaN              NaN
# 75%                       5.00                 4.97      NaN              NaN
# max                       5.00                 5.00      NaN              NaN
#
#         calculated_host_listings_count  \
# count                         12495.00
# unique                             NaN
# top                                NaN
# freq                               NaN
# mean                              5.00
# std                              23.14
# min                               1.00
# 25%                               1.00
# 50%                               1.00
# 75%                               1.00
# max                             181.00
#
#         calculated_host_listings_count_entire_homes  \
# count                                      12495.00
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                           4.75
# std                                           23.16
# min                                            0.00
# 25%                                            1.00
# 50%                                            1.00
# 75%                                            1.00
# max                                          181.00
#
#         calculated_host_listings_count_private_rooms  \
# count                                       12495.00
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# mean                                            0.24
# std                                             0.99
# min                                             0.00
# 25%                                             0.00
# 50%                                             0.00
# 75%                                             0.00
# max                                            18.00
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                      1.25e+04           10191.00
# unique                                          NaN                NaN
# top                                             NaN                NaN
# freq                                            NaN                NaN
# mean                                       4.08e-03               0.76
# std                                        8.33e-02               1.00
# min                                        0.00e+00               0.01
# 25%                                        0.00e+00               0.19
# 50%                                        0.00e+00               0.42
# 75%                                        0.00e+00               0.98
# max                                        3.00e+00              22.13

# %%
# Drop columns with all missing values
count = 0
print('Columns with all values missing:')
for col in df.columns: 
    if df[col].count() == 0:
        print(col)
        dropped_columns.append(col)
        df.drop(col, axis=1, inplace=True)
        count += 1
print(f'dropped {count} columns, shape is now {df.shape}')

# Drop columns with one value
print('\nColumns with one value:')
count = 0
for column in df.columns:
    unique_values = df[column].unique()
    if len(unique_values) == 1:
        print(column)
        dropped_columns.append(column)
        df.drop(column, axis=1, inplace=True)
        count += 1
print(f'Columns with only one value: {count}, shape is now {df.shape}')

# Drop duplicated columns
identical_columns = []
for i in range(df.shape[1]):
    for j in range(i + 1, df.shape[1]):
        if df.iloc[:, i].equals(df.iloc[:, j]):
            identical_columns.append((df.columns[i], df.columns[j]))
print(f"\nIdentical columns: \n{identical_columns}.")
drop_columns = [col[1] for col in identical_columns]
dropped_columns.append(drop_columns)
df.drop(drop_columns, axis=1, inplace=True)
print(f'Dropped {drop_columns}, shape is now {df.shape}')
# Out:
# Columns with all values missing:
# neighbourhood_group_cleansed
# bathrooms
# calendar_updated
# license
# dropped 4 columns, shape is now (12495, 70)
#
# Columns with one value:
# scrape_id
# Columns with only one value: 1, shape is now (12495, 69)
#
# Identical columns:
# [('last_scraped', 'calendar_last_scraped'), ('host_listings_count', 'host_total_listings_count')].
# Dropped ['calendar_last_scraped', 'host_total_listings_count'], shape is now (12495, 67)

# %%
df[['host_neighbourhood', 'host_location', 'neighbourhood', 'neighbourhood_cleansed']].describe()
dropped_columns.append('neighbourhood')
df.drop(['neighbourhood'], axis=1, inplace=True)
print(f"\nDropped neighbourhood as it neighbourhood_cleansed is more accurate, shape is now {df.shape}")

# Host location is the host's origin
# Host neighbourhood is where the host lives
# Neighbourhood and neighbourhood_cleansed is the neighbourhood of the listing
# Out:
# Dropped neighbourhood as it neighbourhood_cleansed is more accurate, shape is now (12495, 66)

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(22, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numeric Columns")
plt.show()

# %%
total_rows = len(df)
missing_values_percent = (df.isnull().sum() / total_rows) * 100
missing_values_percent = missing_values_percent[missing_values_percent > 0.1]
missing_values_percent_df = missing_values_percent.reset_index()
missing_values_percent_df.columns = ['Column', 'Percentage of Missing Values']

columns_with_missing_data = missing_values_percent_df['Column'].tolist()
df_subset = df[columns_with_missing_data]
plt.figure(figsize=(5, 3))
msno.matrix(df_subset)
plt.show()

# %%
plt.figure(figsize=(5, 3))
msno.bar(df_subset)
plt.show()

# %% [markdown]
# # Devide the data into several parts...?

# %%
# Drop URls as they are not important for analysis
url = ['listing_url', 'host_url', 'picture_url', 'host_picture_url', 'host_thumbnail_url']
url_df = df[url]
df.drop(url, axis=1, inplace=True)
print(f"\nMoved all urls to it's own df, shape is now {df.shape}")
# Out:
# Moved all urls to it's own df, shape is now (12495, 61)

# %%
host_columns = df[['id', 'host_id', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_neighbourhood', 'host_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified']]
listing_info_columns = df[['id', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 'amenities', 'price']]

# %% [markdown]
# # Fixing up columns

# %%
# fixing price
df['price'] = df['price'].str.replace('$', '').str.replace(',', '')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# fixing bathrooms_text

# %% [markdown]
# # Create new columns
